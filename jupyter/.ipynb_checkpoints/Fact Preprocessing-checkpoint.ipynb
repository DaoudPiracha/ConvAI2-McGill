# %%
import pandas as pd

# %%
temp = pd.read_csv('/Users/Daoud/ParlAI/data/ConvAI2/train_both_original.txt', delimiter='/n', header=None)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
self = temp.loc[temp[0].str.contains('your persona:')]

# %%
self['number'], self['fact'] = zip(*self[0].str.split('your persona:'))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
self = self[['number', 'fact']]

# %%
self
# Out:
#        number                                               fact
# 0          1                            i like to remodel homes.
# 1          2                               i like to go hunting.
# 2          3                              i like to shoot a bow.
# 3          4                   my favorite holiday is halloween.
# 15         1                           my mom is my best friend.
# 16         2                                i have four sisters.
# 17         3                   i believe that mermaids are real.
# 18         4                                    i love iced tea.
# 30         1            i had a gig at local theater last night.
# 31         2                      i work as a stand up comedian.
# 32         3                           i come from a small town.
# 33         4                    my favorite drink is cuba libre.
# 34         5               i did a few small roles in tv series.
# ...
